# %% [markdown]
# ### bs4 installed version

# %%
print(bs4.__version__)
# Out:
# 4.6.0

# %%
from bs4 import BeautifulSoup

f=open("publist_super_clean.html", 'r')
soup= BeautifulSoup(f.read(),'lxml')

# %%
det=soup.find_all('li')

# %%
data1=[]
data2=[]
data3=[]
data4=[]
data5=[]

for z in range(len(det)):
    url=(det[z].find('a'))
    if url is not None:
        url=url.attrs['href']
        data1.append(url)
        print(url)
    else:
        data1.append('-')
        
    
    name=(det[z].find('a'))    
    if name is not None:
        name=name.text
        name=name.replace('\n','')
        data2.append(name)
        print(name)
    else:
        data2.append('-')
    
    
    
    author0=(det[z].find('a'))
    if author0 is not None:
        author=(((((author0)).next_element).next_element).next_element).next_element
        author=author.replace('\n','')
        data3.append(author)
        print (author)
    else:
        data3.append('-')
    
    journal0=(det[z].find('i'))
    
    if journal0 is not None:
        journal=journal0.text
        journal=journal.replace('\n','')
        data4.append(journal)
        print(journal)

    else:
        data4.append('-')
    

    volume=(det[z].find('b'))
    if volume is not None:
        volume=volume.text
        data5.append(volume)
        print(volume)
    else:
        data5.append('-')
    print("++++++++++++++++++++++++")
# Out:
# Papers/2011/PhysRevB_84_125411_2011.pdf
# "Approaching the intrinsic band gap in suspended high-mobility graphene nanoribbons"
# Ming-Wei Lin, Cheng Ling, Luis A. Agapito, Nicholas Kioussis, Yiyang Zhang, Mark Ming-Cheng Cheng,
# PHYSICAL REVIEW B
# 84
# ++++++++++++++++++++++++
# Papers/2011/PhysRevB_84_035325_2011.pdf
# "Effect of symmetry breaking on the optical absorption of semiconductor nanoparticles"
# JAdam Gali, Efthimios Kaxiras, Gergely T. Zimanyi, Sheng Meng,
# PHYSICAL REVIEW B
# 84
# ++++++++++++++++++++++++
# Papers/2011/PhysRevB_83_054204_2011.pdf
# "Influence of CH2 content and network defects on the elastic properties of organosilicate glasses"
# Jan M. Knaup, Han Li, Joost J. Vlassak, and Efthimios Kaxiras,
# PHYSICAL REVIEW B
# 83
# ++++++++++++++++++++++++
# Papers/2011/PhysRevB_83_045303_2011.pdf
# "Direct correlation of crystal structure and optical properties in wurtzite/zinc-blendeGaAs nanowire heterostructures"
# Martin Heiss, Sonia Conesa-Boj, Jun Ren, Hsiang-Han Tseng, Adam Gali,
# PHYSICAL REVIEW B
# 83
# ++++++++++++++++++++++++
# Papers/2011/PhilTransRSocA_369_2354_2011.pdf
# "Endothelial shear stress from large-scale blood flow simulations"
# Simone Melchionna, Efthimios Kaxiras, Massimo Bernaschi and Sauro Succi,
# Phil. Trans. R. Soc. A
# 369
# ++++++++++++++++++++++++
# Papers/2011/NewJPhys_13_025025_2011.pdf
# "Properties of nitrogen-vacancy centers in diamond:the group theoretic approach"
# J R Maze, A Gali, E Togan, Y Chu, A Trifonov,
# New Journal of Physics
# 13
# ++++++++++++++++++++++++
# Papers/2011/NanoLett_11_2962-2967_2011.pdf
# "Lithium-Assisted Plastic Deformation of Silicon Electrodes inLithium-Ion Batteries: A First-Principles Theoretical Study"
# Kejie Zhao, Wei L. Wang, John Gregoire, Matt Pharr, Zhigang Suo,
# Nano Lett.
# 11
# ++++++++++++++++++++++++
# Papers/2011/Langmuir_27_14248_2011.pdf
# "D-Ï€-A Dye System Containing Cyano-Benzoic Acid as AnchoringGroup for Dye-Sensitized Solar Cells"
#  Masataka Katono, Takeru Bessho, Sheng Meng, Robin Humphry-Baker, Guido Rothenberger,
# Langmuir
# 27
# ++++++++++++++++++++++++
# Papers/2011/JPhysChemLett_2_105-113_2011.pdf
# "New Insights into the Structure of the Vapor/WaterInterface from Large-Scale First-Principles Simulations"
#  Thomas D. Kuhne, Tod A. Pascal, Efthimios Kaxiras, and Yousung Jung,
# J. Phys. Chem. Lett.
# 2
# ++++++++++++++++++++++++
# Papers/2011/JPhysChemC_115_9276-9282_2011.pdf
# "Design of Dye Acceptors for Photovoltaics from First-PrinciplesCalculations"
#  Sheng Meng, Efthimios Kaxiras, Md. K. Nazeeruddin, and Michael Gratzel,
# J. Phys. Chem. C
# 115
# ++++++++++++++++++++++++
# Papers/2011/JPhysChemC_115_3703-3708_2011.pdf
# "Theoretical Study of O-Assisted Selective Coupling of Methanol onAu(111)"
#  Bingjun Xu, Jan Haubrich, Thomas A. Baker, Efthimios Kaxiras, and Cynthia M. Friend,
# J. Phys. Chem. C
# 115
# ++++++++++++++++++++++++
# Papers/2011/JChemPhys_134_194706_2011.pdf
# "Properties of copper (fluoro-)phthalocyanine layers depositedon epitaxial graphene"
#  Jun Ren, Sheng Meng, Yi-Lin Wang, Xu-Cun Ma, Qi-Kun Xue, Efthimios Kaxiras,
# J. Chem. Phys.
# 134
# ++++++++++++++++++++++++
# Papers/2011/Chemistry_17_4496-4506_2011.pdf
# "The Role of Surface and Subsurface Point Defects for Chemical ModelStudies on TiO2: A First-Principles Theoretical Study of FormaldehydeBonding on Rutile TiO2(110)"
#  Jan Haubrich, Efthimios Kaxiras, and Cynthia M. Friend,
# Chem. Eur. J.
# 17
# ++++++++++++++++++++++++
# Papers/2011/CatalSciTechnol_1_1166_2011.pdf
# "Role of defects in propene adsorption and reaction on a partiallyO-covered Au(111) surface"
#  Thomas A. Baker, Bingjun Xu, Stephen C. Jensen, Cynthia M. Friend and Efthimios Kaxiras,
# Catal. Sci. Technol.
# 1
# ++++++++++++++++++++++++
# Papers/2011/ACSNano_5_1395-1400_2011.pdf
# "Graphene Structures at an ExtremeDegree of Buckling"
#  Youdong Mao, Wei L. Wang, Dongguang Wei, Efthimios Kaxiras, and Joseph G. Sodroski,
# ACSNano.
# 5
# ++++++++++++++++++++++++
# Papers/ActaMater_59_44-52_2011.pdf
# "Stiffening of organosilicate glasses by organic cross-linking"
#  H. Li, J.M. Knaup, E. Kaxiras and J.J. Vlassak,
# Acta Mater.
# 59
# ++++++++++++++++++++++++
# Papers/NewJPhys_12_125012_2010.pdf
# "Graphene hydrate: theoretical prediction of a new insulating form of graphene"
#  W.L. Wang and E. Kaxiras,
# New J. Phys.
# 12
# ++++++++++++++++++++++++
# Papers/PhysRevB_82_201411_2010.pdf
# "Electric-field control of magnetism in graphene quantum dots: Ab initio calculations"
#  L.A. Agapito, N. Kioussis and E. Kaxiras,
# Phys. Rev. B
# 82
# ++++++++++++++++++++++++
# Papers/IEEE-SC10_2010.pdf
# "Multiscale simulation of cardiovascular flows on the IBM Bluegene/P: full heart-circulation system at near red-blood cell resolution"
#  A. Peters, S. Melchionna, E. Kaxiras, J. Latt, J. Sircar, S. Succi,
# 2010 ACM/IEEE International Conference for High Performance
# ++++++++++++++++++++++++
# Papers/MolPhys_108_1829-1844_2010.pdf
# "Optical properties of clusters and molecules from real-time time-dependentdensity functional theory using a self-consistent field"
#  J. Ren, E. Kaxiras and S. Meng,
# Molec. Phys.
# 108
# ++++++++++++++++++++++++
# Papers/TopicsCatal_53_365-377_2010.pdf
# "Insights from Theory on the Relationship Between Surface Reactivityand Gold Atom Release"
#  T.A. Baker, E. Kaxiras and C.M. Friend,
# Top. Catal.
# 53
# ++++++++++++++++++++++++
# Papers/PhysRevLett_104_155502_2010.pdf
# "Embrittlement of Metal by Solute Segregation-Induced Amorphization"
#  H.P. Chen, R.K. Kalia, E. Kaxiras, G. Lu, A. Nakano, K. Nomura,
# Phys. Rev. Lett.
# 104
# ++++++++++++++++++++++++
# Papers/NanoLett_10_1238-1247_2010.pdf
# "Electron and Hole Dynamics in Dye-Sensitized Solar Cells:Influencing Factors and Systematic Trends"
#  S. Meng and E. Kaxiras,
# NanoLett.
# 10
# ++++++++++++++++++++++++
# Papers/PhysRevB_81_085406_2010.pdf
# "Compositional tuning of ultrathin surface oxides on metal and alloysubstrates using photons: Dynamic simulations and experiments"
#  C.L. Chang, S.K.R.S. Sankaranarayanan, D. Ruzmetov, M.H. Engelhard, E. Kaxiras and S. Ramanathan,
# Phys. Rev. B
# 81
# ++++++++++++++++++++++++
# Papers/JChemTheComp_6_279-287_2010.pdf
# "Local Bonding Effects in the Oxidation of CO on Oxygen-CoveredAu(111) from Ab Initio Molecular Dynamics Simulations"
#  T.A. Baker, C.M. Friend and E. Kaxiras,
# J. Chem. Theory Comput.
# 6
# ++++++++++++++++++++++++
# Papers/CompPhysComm_181_462-472_2010.pdf
# "Hydrokinetic approach to large-scale cardiovascular blood flow"
#  S. Melchionna, M. Bernaschi, S. Succi, E. Kaxiras, F.J. Rybicki, D. Mitsouras, A.U. Coskun and C.L. Feldman,
# Comp. Phys. Comm.
# 181
# ++++++++++++++++++++++++
# Papers/ConcComp_22_1-14_2010.pdf
# "A flexible high-performance Lattice Boltzmann GPU code for thesimulations of fluid flows in complex geometries"
#  M. Bernaschi, M. Fatica, S. Melchionna, S. Succi and E. Kaxiras,
# Concurrency Computat.: Pract. Exper.
# 22
# ++++++++++++++++++++++++
# Papers/SolStComm_150_62-65_2010.pdf
# "Is the nature of magnetic order in copper-oxides and iron-pnictides different?"
#  E. Manousakis, J. Ren, S. Meng and E. Kaxiras,
# Sol. St. Comm.
# 150
# ++++++++++++++++++++++++
# Papers/PhysRevLett_103_186404_2009.pdf
# "Theory of Spin-Conserving Excitation of the N-V Center in Diamond"
#  A. Gali, E. Janzen, P. Deak, G. Kresse and E. Kaxiras,
# Phys. Rev. Lett.
# 103
# ++++++++++++++++++++++++
# Papers/EnEnviSci_2_1196-1204_2009.pdf
# "Electric field tuning of oxygen stoichiometry at oxide surfaces:molecular dynamics isimulations studies iof zirconia"
#  S.K.R.S. Sankaranarayanan, E. Kaxiras and S. Ramanathan,
# Energy & Environmental Sci.
# 2
# ++++++++++++++++++++++++
# Papers/CompPhysComm_180_1495-1502_2009.pdf
# "MUPHY: A parallel MUlti PHYsics/scale code for high performance bio-fluidic simulations"
#  M. Bernaschi, S. Melchionna, S. Succi, M. Fyta, E. Kaxiras
# Comp. Phys. Comm.
# 180
# ++++++++++++++++++++++++
# Papers/JPhysChemC_113_16561-16564_2009.pdf
# "Nature of Oxidation of the Au(111) Surface: Experiment andTheoretical Investigation"
#  T.A. Baker, B.J. Xu, X.Y. Liu, E. Kaxiras and C.M. Friend,
# J. Phys. Chem. C
# 113
# ++++++++++++++++++++++++
# Papers/IntJCardImag_25_289-299_2009.pdf
# "Prediction of coronary artery plaque progression and potential rupturefrom 320-detector row prospectively ECG-gated single heart beat CT angiography: Lattice Boltzmann evaluation of endothelial shear stress"
#  F.J. Rybicki, S. Melchionna, D. Mitsouras, A.U. Coskun, A.G. Whitmore, E. Kaxiras, S. Succi, P.H. Stone and C.L. Feldman,
# Int. J. Cardiovasc. Imaging
# 25
# ++++++++++++++++++++++++
# Papers/PhysRevB_79_235202_2009.pdf
# "Optimization of Mn doping in group-IV-based dilute magnetic semiconductorsby electronic codopants"
#  H. Chen, W.G. Zhu, E. Kaxiras, and Z.Y. Zhang,
# Phys. Rev. B
# 79
# ++++++++++++++++++++++++
# Papers/JStatMech_2009.pdf
# "Numerical simulation of conformational variability in biopolymer translocation through wide nanopores"
#  M. Fyta, S. Melchionna, M. Bernaschi, E. Kaxiras and S. Succi,
# J. Stat. Mech: Th. and Exper.
# 06
# ++++++++++++++++++++++++
# Papers/PhysRevE_79_045701RC_2009.pdf
# "Control algorithm for multiscale flow simulations of water"
#  E.M. Kotsalis, J.H. Walther, E. Kaxiras and P. Koumoutsakos,
# Phys. Rev. E - Rap. Comm.
# 79
# ++++++++++++++++++++++++
# Papers/JPhysChemB_113_6478_2009.pdf
# "Structural, Electronic, and Optical Properties of Representative Cu-Flavonoid Complexes"
# C.E. Lekka, J. Ren, S. Meng and E. Kaxiras,
# J. Phys. Chem. B
# 113
# ++++++++++++++++++++++++
# Papers/PhysRevLett_102_157201_2009.pdf
# "Topological Frustration in Graphene Nanoflakes: Magnetic Order and Spin Logic Devices"
#  W.L. Wang, O.V. Yazyev, S. Meng and E. Kaxiras,
# Phys. Rev. Lett.
# 102
# ++++++++++++++++++++++++
# Papers/PhysRevLett_102_149703_2009.pdf
# "Comment on 'Ab initio Electronic and Optical Properties of the N-V-Center in Diamond'"
#  Electronic and Optical Properties of the N-V-Center in Diamond'"
# Ab initio
# 102
# ++++++++++++++++++++++++
# Papers/PhysRevE_79_030901RC_2009.pdf
# "Quantized biopolymer translocation through nanopores: Departure from simple scaling"
#  S. Melchionna, M. Bernaschi, M. Fyta, E. Kaxiras and S. Succi,
# Phys. Rev. E - Rap. Comm.
# 79
# ++++++++++++++++++++++++
# Papers/PhysRevLett_102_095504_2009.pdf
# "Atomistic Simulation of Field Enhanced Oxidation of Al(1000) Beyond the Mott Potential"
# S.K.R.S. Sankaranarayanan, E. Kaxiras, S. Ramanathan,
# Phys. Rev. Lett.
# 102
# ++++++++++++++++++++++++
# Papers/JChemPhys_130_084701_2009.pdf
# "Effects of chlorine and oxygen coverage on the structure of the Au(111) surface"
# T.A. Baker, C.M. Friend and E. Kaxiras,
# J. Chem. Phys.
# 130
# ++++++++++++++++++++++++
# Papers/JPhysChemC_113_3232_2009.pdf
# "Atomic Oxygen Adsorption on Au(111) Surfaces with Defects"
# T.A. Baker, C.M. Friend and E. Kaxiras,
# J. Phys. Chem. C
# 113
# ++++++++++++++++++++++++
# Papers/SciModSim_15_59_2008.pdf
# "Multiscale simulations of complex systems: computation meets reality"
# E. Kaxiras and S. Succi,
# Sci. Model. Simul.
# 15
# ++++++++++++++++++++++++
# Papers/PhysRevB_78_205112_2008.pdf
# "Effective Hamiltonian for FeAs-based superconductors"
# E. Manousakis, J. Ren, S. Meng and E. Kaxiras,
# Phys. Rev. B
# 78
# ++++++++++++++++++++++++

# %%
jsonList = []
for i in range(0,len(data1)):
    jsonList.append({'Url': data1[i],'Name': data2[i],'Authors': data3[i],'Journal': data4[i],'Volume': data5[i]})

# %%
jsonList
# Out:
# [{'Authors': 'Ming-Wei Lin, Cheng Ling, Luis A. Agapito, Nicholas Kioussis, Yiyang Zhang, Mark Ming-Cheng Cheng,',
#   'Journal': 'PHYSICAL REVIEW B ',
#   'Name': '"Approaching the intrinsic band gap in suspended high-mobility graphene nanoribbons"',
#   'Url': 'Papers/2011/PhysRevB_84_125411_2011.pdf',
#   'Volume': '84'},
#  {'Authors': 'JAdam Gali, Efthimios Kaxiras, Gergely T. Zimanyi, Sheng Meng,',
#   'Journal': 'PHYSICAL REVIEW B ',
#   'Name': '"Effect of symmetry breaking on the optical absorption of semiconductor nanoparticles"',
#   'Url': 'Papers/2011/PhysRevB_84_035325_2011.pdf',
#   'Volume': '84'},
#  {'Authors': 'Jan M. Knaup, Han Li, Joost J. Vlassak, and Efthimios Kaxiras,',
#   'Journal': 'PHYSICAL REVIEW B ',
#   'Name': '"Influence of CH2 content and network defects on the elastic properties of organosilicate glasses"',
#   'Url': 'Papers/2011/PhysRevB_83_054204_2011.pdf',
#   'Volume': '83'},
#  {'Authors': 'Martin Heiss, Sonia Conesa-Boj, Jun Ren, Hsiang-Han Tseng, Adam Gali,',
#   'Journal': 'PHYSICAL REVIEW B ',
#   'Name': '"Direct correlation of crystal structure and optical properties in wurtzite/zinc-blendeGaAs nanowire heterostructures"',
#   'Url': 'Papers/2011/PhysRevB_83_045303_2011.pdf',
#   'Volume': '83'},
#  {'Authors': 'Simone Melchionna, Efthimios Kaxiras, Massimo Bernaschi and Sauro Succi, ',
#   'Journal': 'Phil. Trans. R. Soc. A ',
#   'Name': '"Endothelial shear stress from large-scale blood flow simulations"',
#   'Url': 'Papers/2011/PhilTransRSocA_369_2354_2011.pdf',
#   'Volume': '369'},
#  {'Authors': 'J R Maze, A Gali, E Togan, Y Chu, A Trifonov,',
#   'Journal': 'New Journal of Physics ',
#   'Name': '"Properties of nitrogen-vacancy centers in diamond:the group theoretic approach"',
#   'Url': 'Papers/2011/NewJPhys_13_025025_2011.pdf',
#   'Volume': '13'},
#  {'Authors': 'Kejie Zhao, Wei L. Wang, John Gregoire, Matt Pharr, Zhigang Suo,',
#   'Journal': 'Nano Lett. ',
#   'Name': '"Lithium-Assisted Plastic Deformation of Silicon Electrodes inLithium-Ion Batteries: A First-Principles Theoretical Study"',
#   'Url': 'Papers/2011/NanoLett_11_2962-2967_2011.pdf',
#   'Volume': '11'},
#  {'Authors': ' Masataka Katono, Takeru Bessho, Sheng Meng, Robin Humphry-Baker, Guido Rothenberger,',
#   'Journal': 'Langmuir ',
#   'Name': '"D-Ï€-A Dye System Containing Cyano-Benzoic Acid as AnchoringGroup for Dye-Sensitized Solar Cells"',
#   'Url': 'Papers/2011/Langmuir_27_14248_2011.pdf',
#   'Volume': '27'},
#  {'Authors': ' Thomas D. Kuhne, Tod A. Pascal, Efthimios Kaxiras, and Yousung Jung,',
#   'Journal': 'J. Phys. Chem. Lett. ',
#   'Name': '"New Insights into the Structure of the Vapor/WaterInterface from Large-Scale First-Principles Simulations"',
#   'Url': 'Papers/2011/JPhysChemLett_2_105-113_2011.pdf',
#   'Volume': '2'},
#  {'Authors': ' Sheng Meng, Efthimios Kaxiras, Md. K. Nazeeruddin, and Michael Gratzel,',
#   'Journal': 'J. Phys. Chem. C ',
#   'Name': '"Design of Dye Acceptors for Photovoltaics from First-PrinciplesCalculations"',
#   'Url': 'Papers/2011/JPhysChemC_115_9276-9282_2011.pdf',
#   'Volume': '115'},
#  {'Authors': ' Bingjun Xu, Jan Haubrich, Thomas A. Baker, Efthimios Kaxiras, and Cynthia M. Friend,',
#   'Journal': 'J. Phys. Chem. C ',
#   'Name': '"Theoretical Study of O-Assisted Selective Coupling of Methanol onAu(111)"',
#   'Url': 'Papers/2011/JPhysChemC_115_3703-3708_2011.pdf',
#   'Volume': '115'},
#  {'Authors': ' Jun Ren, Sheng Meng, Yi-Lin Wang, Xu-Cun Ma, Qi-Kun Xue, Efthimios Kaxiras,',
#   'Journal': 'J. Chem. Phys. ',
#   'Name': '"Properties of copper (fluoro-)phthalocyanine layers depositedon epitaxial graphene"',
#   'Url': 'Papers/2011/JChemPhys_134_194706_2011.pdf',
#   'Volume': '134'},
#  {'Authors': ' Jan Haubrich, Efthimios Kaxiras, and Cynthia M. Friend,',
#   'Journal': 'Chem. Eur. J. ',
#   'Name': '"The Role of Surface and Subsurface Point Defects for Chemical ModelStudies on TiO2: A First-Principles Theoretical Study of FormaldehydeBonding on Rutile TiO2(110)"',
#   'Url': 'Papers/2011/Chemistry_17_4496-4506_2011.pdf',
#   'Volume': '17'},
#  {'Authors': ' Thomas A. Baker, Bingjun Xu, Stephen C. Jensen, Cynthia M. Friend and Efthimios Kaxiras,',
#   'Journal': 'Catal. Sci. Technol. ',
#   'Name': '"Role of defects in propene adsorption and reaction on a partiallyO-covered Au(111) surface"',
#   'Url': 'Papers/2011/CatalSciTechnol_1_1166_2011.pdf',
#   'Volume': '1'},
#  {'Authors': ' Youdong Mao, Wei L. Wang, Dongguang Wei, Efthimios Kaxiras, and Joseph G. Sodroski,',
#   'Journal': 'ACSNano. ',
#   'Name': '"Graphene Structures at an ExtremeDegree of Buckling"',
#   'Url': 'Papers/2011/ACSNano_5_1395-1400_2011.pdf',
#   'Volume': '5'},
#  {'Authors': ' H. Li, J.M. Knaup, E. Kaxiras and J.J. Vlassak,',
#   'Journal': 'Acta Mater. ',
#   'Name': '"Stiffening of organosilicate glasses by organic cross-linking"',
#   'Url': 'Papers/ActaMater_59_44-52_2011.pdf',
#   'Volume': '59'},
#  {'Authors': ' W.L. Wang and E. Kaxiras,',
#   'Journal': 'New J. Phys. ',
#   'Name': '"Graphene hydrate: theoretical prediction of a new insulating form of graphene"',
#   'Url': 'Papers/NewJPhys_12_125012_2010.pdf',
#   'Volume': '12'},
#  {'Authors': ' L.A. Agapito, N. Kioussis and E. Kaxiras,',
#   'Journal': 'Phys. Rev. B ',
#   'Name': '"Electric-field control of magnetism in graphene quantum dots: Ab initio calculations"',
#   'Url': 'Papers/PhysRevB_82_201411_2010.pdf',
#   'Volume': '82'},
#  {'Authors': ' A. Peters, S. Melchionna, E. Kaxiras, J. Latt, J. Sircar, S. Succi, ',
#   'Journal': '2010 ACM/IEEE International Conference for High Performance ',
#   'Name': '"Multiscale simulation of cardiovascular flows on the IBM Bluegene/P: full heart-circulation system at near red-blood cell resolution"',
#   'Url': 'Papers/IEEE-SC10_2010.pdf',
#   'Volume': '-'},
#  {'Authors': ' J. Ren, E. Kaxiras and S. Meng, ',
#   'Journal': 'Molec. Phys. ',
#   'Name': '"Optical properties of clusters and molecules from real-time time-dependentdensity functional theory using a self-consistent field"',
#   'Url': 'Papers/MolPhys_108_1829-1844_2010.pdf',
#   'Volume': '108'},
#  {'Authors': ' T.A. Baker, E. Kaxiras and C.M. Friend, ',
#   'Journal': 'Top. Catal. ',
#   'Name': '"Insights from Theory on the Relationship Between Surface Reactivityand Gold Atom Release"',
#   'Url': 'Papers/TopicsCatal_53_365-377_2010.pdf',
#   'Volume': '53'},
#  {'Authors': ' H.P. Chen, R.K. Kalia, E. Kaxiras, G. Lu, A. Nakano, K. Nomura,',
#   'Journal': 'Phys. Rev. Lett. ',
#   'Name': '"Embrittlement of Metal by Solute Segregation-Induced Amorphization"',
#   'Url': 'Papers/PhysRevLett_104_155502_2010.pdf',
#   'Volume': '104'},
#  {'Authors': ' S. Meng and E. Kaxiras,',
#   'Journal': 'NanoLett. ',
#   'Name': '"Electron and Hole Dynamics in Dye-Sensitized Solar Cells:Influencing Factors and Systematic Trends"',
#   'Url': 'Papers/NanoLett_10_1238-1247_2010.pdf',
#   'Volume': '10'},
#  {'Authors': ' C.L. Chang, S.K.R.S. Sankaranarayanan, D. Ruzmetov, M.H. Engelhard, E. Kaxiras and S. Ramanathan, ',
#   'Journal': 'Phys. Rev. B ',
#   'Name': '"Compositional tuning of ultrathin surface oxides on metal and alloysubstrates using photons: Dynamic simulations and experiments"',
#   'Url': 'Papers/PhysRevB_81_085406_2010.pdf',
#   'Volume': '81'},
#  {'Authors': ' T.A. Baker, C.M. Friend and E. Kaxiras, ',
#   'Journal': 'J. Chem. Theory Comput. ',
#   'Name': '"Local Bonding Effects in the Oxidation of CO on Oxygen-CoveredAu(111) from Ab Initio Molecular Dynamics Simulations"',
#   'Url': 'Papers/JChemTheComp_6_279-287_2010.pdf',
#   'Volume': '6'},
#  {'Authors': ' S. Melchionna, M. Bernaschi, S. Succi, E. Kaxiras, F.J. Rybicki, D. Mitsouras, A.U. Coskun and C.L. Feldman, ',
#   'Journal': 'Comp. Phys. Comm. ',
#   'Name': '"Hydrokinetic approach to large-scale cardiovascular blood flow"',
#   'Url': 'Papers/CompPhysComm_181_462-472_2010.pdf',
#   'Volume': '181'},
#  {'Authors': ' M. Bernaschi, M. Fatica, S. Melchionna, S. Succi and E. Kaxiras, ',
#   'Journal': 'Concurrency Computat.: Pract. Exper. ',
#   'Name': '"A flexible high-performance Lattice Boltzmann GPU code for thesimulations of fluid flows in complex geometries"',
#   'Url': 'Papers/ConcComp_22_1-14_2010.pdf',
#   'Volume': '22'},
#  {'Authors': ' E. Manousakis, J. Ren, S. Meng and E. Kaxiras, ',
#   'Journal': 'Sol. St. Comm. ',
#   'Name': '"Is the nature of magnetic order in copper-oxides and iron-pnictides different?"',
#   'Url': 'Papers/SolStComm_150_62-65_2010.pdf',
#   'Volume': '150'},
#  {'Authors': ' A. Gali, E. Janzen, P. Deak, G. Kresse and E. Kaxiras, ',
#   'Journal': 'Phys. Rev. Lett. ',
#   'Name': '"Theory of Spin-Conserving Excitation of the N-V Center in Diamond"',
#   'Url': 'Papers/PhysRevLett_103_186404_2009.pdf',
#   'Volume': '103'},
#  {'Authors': ' S.K.R.S. Sankaranarayanan, E. Kaxiras and S. Ramanathan, ',
#   'Journal': 'Energy & Environmental Sci. ',
#   'Name': '"Electric field tuning of oxygen stoichiometry at oxide surfaces:molecular dynamics isimulations studies iof zirconia"',
#   'Url': 'Papers/EnEnviSci_2_1196-1204_2009.pdf',
#   'Volume': '2'},
#  {'Authors': ' M. Bernaschi, S. Melchionna, S. Succi, M. Fyta, E. Kaxiras ',
#   'Journal': 'Comp. Phys. Comm. ',
#   'Name': '"MUPHY: A parallel MUlti PHYsics/scale code for high performance bio-fluidic simulations"',
#   'Url': 'Papers/CompPhysComm_180_1495-1502_2009.pdf',
#   'Volume': '180'},
#  {'Authors': ' T.A. Baker, B.J. Xu, X.Y. Liu, E. Kaxiras and C.M. Friend, ',
#   'Journal': 'J. Phys. Chem. C ',
#   'Name': '"Nature of Oxidation of the Au(111) Surface: Experiment andTheoretical Investigation"',
#   'Url': 'Papers/JPhysChemC_113_16561-16564_2009.pdf',
#   'Volume': '113'},
#  {'Authors': ' F.J. Rybicki, S. Melchionna, D. Mitsouras, A.U. Coskun, A.G. Whitmore, E. Kaxiras, S. Succi, P.H. Stone and C.L. Feldman,  ',
#   'Journal': 'Int. J. Cardiovasc. Imaging ',
#   'Name': '"Prediction of coronary artery plaque progression and potential rupturefrom 320-detector row prospectively ECG-gated single heart beat CT angiography: Lattice Boltzmann evaluation of endothelial shear stress"',
#   'Url': 'Papers/IntJCardImag_25_289-299_2009.pdf',
#   'Volume': '25'},
#  {'Authors': ' H. Chen, W.G. Zhu, E. Kaxiras, and Z.Y. Zhang,',
#   'Journal': 'Phys. Rev. B ',
#   'Name': '"Optimization of Mn doping in group-IV-based dilute magnetic semiconductorsby electronic codopants"',
#   'Url': 'Papers/PhysRevB_79_235202_2009.pdf',
#   'Volume': '79'},
#  {'Authors': ' M. Fyta, S. Melchionna, M. Bernaschi, E. Kaxiras and S. Succi,',
#   'Journal': 'J. Stat. Mech: Th. and Exper. ',
#   'Name': '"Numerical simulation of conformational variability in biopolymer translocation through wide nanopores"',
#   'Url': 'Papers/JStatMech_2009.pdf',
#   'Volume': '06'},
#  {'Authors': ' E.M. Kotsalis, J.H. Walther, E. Kaxiras and P. Koumoutsakos,  ',
#   'Journal': 'Phys. Rev. E - Rap. Comm. ',
#   'Name': '"Control algorithm for multiscale flow simulations of water"',
#   'Url': 'Papers/PhysRevE_79_045701RC_2009.pdf',
#   'Volume': '79'},
#  {'Authors': 'C.E. Lekka, J. Ren, S. Meng and E. Kaxiras,',
#   'Journal': 'J. Phys. Chem. B ',
#   'Name': '"Structural, Electronic, and Optical Properties of Representative Cu-Flavonoid Complexes"',
#   'Url': 'Papers/JPhysChemB_113_6478_2009.pdf',
#   'Volume': '113'},
#  {'Authors': ' W.L. Wang, O.V. Yazyev, S. Meng and E. Kaxiras, ',
#   'Journal': 'Phys. Rev. Lett. ',
#   'Name': '"Topological Frustration in Graphene Nanoflakes: Magnetic Order and Spin Logic Devices"',
#   'Url': 'Papers/PhysRevLett_102_157201_2009.pdf',
#   'Volume': '102'},
#  {'Authors': ' Electronic and Optical Properties of the N-V-Center in Diamond\'"',
#   'Journal': 'Ab initio',
#   'Name': '"Comment on \'Ab initio Electronic and Optical Properties of the N-V-Center in Diamond\'"',
#   'Url': 'Papers/PhysRevLett_102_149703_2009.pdf',
#   'Volume': '102'},
#  {'Authors': ' S. Melchionna, M. Bernaschi, M. Fyta, E. Kaxiras and S. Succi,  ',
#   'Journal': 'Phys. Rev. E - Rap. Comm. ',
#   'Name': '"Quantized biopolymer translocation through nanopores: Departure from simple scaling"',
#   'Url': 'Papers/PhysRevE_79_030901RC_2009.pdf',
#   'Volume': '79'},
#  {'Authors': 'S.K.R.S. Sankaranarayanan, E. Kaxiras, S. Ramanathan,',
#   'Journal': 'Phys. Rev. Lett. ',
#   'Name': '"Atomistic Simulation of Field Enhanced Oxidation of Al(1000) Beyond the Mott Potential"',
#   'Url': 'Papers/PhysRevLett_102_095504_2009.pdf',
#   'Volume': '102'},
#  {'Authors': 'T.A. Baker, C.M. Friend and E. Kaxiras,',
#   'Journal': 'J. Chem. Phys. ',
#   'Name': '"Effects of chlorine and oxygen coverage on the structure of the Au(111) surface"',
#   'Url': 'Papers/JChemPhys_130_084701_2009.pdf',
#   'Volume': '130'},
#  {'Authors': 'T.A. Baker, C.M. Friend and E. Kaxiras,',
#   'Journal': 'J. Phys. Chem. C ',
#   'Name': '"Atomic Oxygen Adsorption on Au(111) Surfaces with Defects"',
#   'Url': 'Papers/JPhysChemC_113_3232_2009.pdf',
#   'Volume': '113'},
#  {'Authors': 'E. Kaxiras and S. Succi, ',
#   'Journal': 'Sci. Model. Simul. ',
#   'Name': '"Multiscale simulations of complex systems: computation meets reality"',
#   'Url': 'Papers/SciModSim_15_59_2008.pdf',
#   'Volume': '15'},
#  {'Authors': 'E. Manousakis, J. Ren, S. Meng and E. Kaxiras, ',
#   'Journal': 'Phys. Rev. B ',
#   'Name': '"Effective Hamiltonian for FeAs-based superconductors"',
#   'Url': 'Papers/PhysRevB_78_205112_2008.pdf',
#   'Volume': '78'}]
